# %%
#-*- coding : utf-8 -*-
# coding: utf-8

import pandas as pd 

odata = pd.read_csv('C:\\mydocuments\\地铁\\20170507.txt',sep ='\s+',encoding = 'gbk',header = None)

odata.columns = ['本次交易设备编号',
                 '本次交易日期时间',
                 '票卡号',
                 '交易金额',
                 '余额',
                 '交易类型',
                 '附加交易类型',
                 '附加交易类型',
                 '票卡消费交易计数',
                 '公交门槛计数',
                 '地铁门槛计数',
                 '联乘门槛计数',
                 '本次交易入口设备编号',
                 '本次交易入口日期时间',
                 '上次交易设备编号',
                 '上次交易日期时间',
                 '卡种',
                 '地铁出站站点',
                 '地铁进站站点']
# Out:
# C:\software\Anconda\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (12,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
odata.head(10)
# Out:
#       本次交易设备编号        本次交易日期时间               票卡号  交易金额   余额    交易类型  附加交易类型  \
# 0  10000070201  20170507171236  5100000946742564  1.90  2.0   28.25       9
# 1  10000084234  20170507140755  5100000935408471  1.20  2.0   40.55       9
# 2  10000091684  20170507083755  5100008504575353  2.85  3.0   24.40       9
# 3  10000069125  20170507214044  5100000924445492  3.80  4.0   82.55       9
# 4  10000069926  20170507184127  5100000476325222  4.75  5.0  168.65       9
# 5  10000069791  20170507141046  5100000943881521  3.80  4.0   49.65       9
# 6  10000071000  20170507075100  5100000926692106  3.80  4.0   65.95       9
# 7  10000139981  20170507132721  5100000926116365  2.85  3.0   44.55       9
# 8  10000140119  20170507135154  5100000704702236  3.60  6.0   20.50       9
# 9  10000070500  20170507163752  5100000906544368  1.80  3.0   38.75       9
#
#    附加交易类型  票卡消费交易计数  公交门槛计数  地铁门槛计数  联乘门槛计数   本次交易入口设备编号      本次交易入口日期时间  \
# ...

# %%
odata['地铁出站站点']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\software\Anconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: '地铁出站站点 == bus2'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-21e59fb30183> in <module>
# ----> 1 odata['地铁出站站点 == bus2']
#
# ...

# %%
odata[odata['地铁进站站点'].isin(['1'])]
# Out:
#             本次交易设备编号        本次交易日期时间               票卡号  交易金额   余额   交易类型  \
# 1073     10000069530  20170507192951  5100000613203950  5.70  6.0  19.95
# 1074     10000085740  20170507210511  5100000944281278  3.80  4.0  52.45
# 1153     10000070101  20170507200418  5100000748914925  4.75  5.0   9.70
# 1159     10000128600  20170507112903  5100000778842063  1.90  2.0   8.80
# 1163     10000154031  20170507084752  5100000900097297  3.80  4.0  86.45
# ...              ...             ...               ...   ...  ...    ...
# 6557267       140124  20170507173142  5100000138815838  3.00  5.0  55.70
# 6557270        44202  20170507120851  5100000191657099  1.90  2.0  98.15
# 6557273        71000  20170507152434  5100000287921420  0.00  5.0   0.00
# 6557297        44073  20170507230616  5100000299296389  2.40  4.0   7.60
# 6557298       143082  20170507172658  5100000291969698  1.50  3.0  65.90
#
#          附加交易类型  附加交易类型  票卡消费交易计数  公交门槛计数  地铁门槛计数  联乘门槛计数   本次交易入口设备编号  \
# ...

# %%
odata[odata['地铁出站站点'].isin(['1'])]
# Out:
#             本次交易设备编号        本次交易日期时间               票卡号  交易金额   余额    交易类型  \
# 8        10000140119  20170507135154  5100000704702236  3.60  6.0   20.50
# 12            154129  20170507112825  5100000527752153  1.00  2.0   12.70
# 28       10000140147  20170507213619  5100000925729937  5.70  6.0   47.80
# 36       10000087121  20170507132841  5100000778842063  1.90  2.0    6.90
# 45       10000140150  20170507115826  5100000925541962  4.75  5.0   19.40
# ...              ...             ...               ...   ...  ...     ...
# 6557442  10000087102  20170507104154  5100000325886766  2.85  3.0   49.35
# 6557444  10000087090  20170507073233  5100000756427709  3.80  4.0   31.10
# 6557452  10000140148  20170507190609  5100000473121740  5.70  6.0    1.90
# 6557454  10000140149  20170507160753  5100000701633539  6.65  7.0  168.75
# 6557467  10000143063  20170507160202  5100000938757370  3.80  4.0   19.30
#
#          附加交易类型  附加交易类型  票卡消费交易计数  公交门槛计数  地铁门槛计数  联乘门槛计数   本次交易入口设备编号  \
# ...
